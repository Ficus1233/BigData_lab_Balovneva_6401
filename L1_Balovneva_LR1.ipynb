# %% [markdown]
# ## Решите следующие задачи для данных велопарковок Сан-Франциско (trips.csv, stations.csv):
#
# 1.	Найти велосипед с максимальным временем пробега.
# 2.	Найти наибольшее геодезическое расстояние между станциями.
# 3.	Найти путь велосипеда с максимальным временем пробега через станции.
# 4.	Найти количество велосипедов в системе.
# 5.	Найти пользователей потративших на поездки более 3 часов.

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.appName("lr1").config("spark.sql.legacy.timeParserPolicy", "LEGACY").getOrCreate()

# %%
trips_df = spark.read.option("header", "true").option("inferSchema", "true").csv("trip.csv")
print(trips_df.dtypes)

stations_df = spark.read.option("header", "true").option("inferSchema", "true").csv("station.csv")
print(stations_df.dtypes)
# Out:
# [('id', 'int'), ('duration', 'int'), ('start_date', 'string'), ('start_station_name', 'string'), ('start_station_id', 'int'), ('end_date', 'string'), ('end_station_name', 'string'), ('end_station_id', 'int'), ('bike_id', 'int'), ('subscription_type', 'string'), ('zip_code', 'string')]
# [('id', 'int'), ('name', 'string'), ('lat', 'double'), ('long', 'double'), ('dock_count', 'int'), ('city', 'string'), ('installation_date', 'string')]

# %%
# Найти велосипед с максимальным временем пробега.
result =(trips_df.groupBy("bike_id")
         .agg((F.sum("duration")/3600).alias("sum_duration"))
         .orderBy(F.desc("sum_duration"))
         .limit(1)
         .select("bike_id", F.round("sum_duration", 1).alias("duration"))
).collect()
print(result)
# Out:
# [Row(bike_id=535, duration=5169.9)]

# %%
# Найти наибольшее геодезическое расстояние между станциями
def calc_dist(lat1, lon1, lat2, lon2):
    R = 6371 # Радиус Земли
    lat1, lat2, lon1, lon2 = F.radians(lat1), F.radians(lat2), F.radians(lon1), F.radians(lon2)
    return R * F.acos(F.sin(lat1) * F.sin(lat2) + F.cos(lat1) * F.cos(lat2) * F.cos(lon2 - lon1))

max_distance = (stations_df.alias("station1")
                .crossJoin(stations_df.alias("station2"))
                .filter(F.col("station1.id") < F.col("station2.id"))
                .withColumn("distance", calc_dist(F.col("station1.lat"), F.col("station1.long"), F.col("station2.lat"), F.col("station2.long")))
                .agg(F.max("distance").alias("max_distance"))
                .collect()[0]["max_distance"])

print(max_distance)
# Out:
# 69.92087595421542

# %%
# Найти путь велосипеда с максимальным временем пробега через станции.

# Первое задание
max_duration_bike =(trips_df.groupBy("bike_id")
         .agg((F.sum("duration")/3600).alias("sum_duration"))
         .orderBy(F.desc("sum_duration"))
         .limit(1)
         .select("bike_id", F.round("sum_duration", 1))
).collect()

bike_trips = (trips_df.filter(F.col("bike_id")==max_duration_bike[0]["bike_id"])
             .select("start_date", "start_station_name", "end_date", "end_station_name")
             .orderBy("start_date")
).collect()

print(bike_trips)
# Out:
# [Row(start_date='1/1/2014 13:42', start_station_name='Mechanics Plaza (Market at Battery)', end_date='1/1/2014 14:36', end_station_name='Embarcadero at Sansome'), Row(start_date='1/1/2014 18:51', start_station_name='Embarcadero at Sansome', end_date='1/1/2014 19:13', end_station_name='Market at 4th'), Row(start_date='1/1/2014 19:48', start_station_name='Market at 4th', end_date='1/1/2014 20:01', end_station_name='South Van Ness at Market'), Row(start_date='1/10/2014 20:13', start_station_name='Market at 10th', end_date='1/10/2014 20:17', end_station_name='Powell Street BART'), Row(start_date='1/10/2014 8:09', start_station_name='Embarcadero at Folsom', end_date='1/10/2014 8:19', end_station_name='San Francisco Caltrain (Townsend at 4th)'), Row(start_date='1/10/2014 8:21', start_station_name='San Francisco Caltrain (Townsend at 4th)', end_date='1/10/2014 8:31', end_station_name='Temporary Transbay Terminal (Howard at Beale)'), Row(start_date='1/10/2014 9:19', start_station_name='Temporary Transbay Terminal (Howard at Beale)', end_date='1/10/2014 9:32', end_station_name='Market at 10th'), Row(start_date='1/11/2014 19:06', start_station_name='Powell Street BART', end_date='1/11/2014 19:11', end_station_name='Market at 10th'), Row(start_date='1/12/2014 12:21', start_station_name='Market at 10th', end_date='1/12/2014 12:29', end_station_name='Market at 4th'), Row(start_date='1/12/2014 17:36', start_station_name='Market at 4th', end_date='1/12/2014 17:58', end_station_name='San Francisco Caltrain (Townsend at 4th)'), Row(start_date='1/13/2014 17:04', start_station_name='Davis at Jackson', end_date='1/13/2014 17:06', end_station_name='Beale at Market'), Row(start_date='1/13/2014 18:09', start_station_name='Beale at Market', end_date='1/13/2014 18:13', end_station_name='Davis at Jackson'), Row(start_date='1/13/2014 6:43', start_station_name='San Francisco Caltrain (Townsend at 4th)', end_date='1/13/2014 6:54', end_station_name='Embarcadero at Vallejo'), Row(start_date='1/13/2014 8:20', start_station_name='San Francisco Caltrain (Townsend at 4th)', end_date='1/13/2014 8:31', end_station_name='Market at Sansome'), Row(start_date='1/13/2014 8:52', start_station_name='Market at Sansome', end_date='1/13/2014 8:56', end_station_name='Davis at Jackson'), Row(start_date='1/14/2014 11:52', start_station_name='Howard at 2nd', end_date='1/14/2014 11:55', end_station_name='2nd at South Park'), Row(start_date='1/14/2014 13:12', start_station_name='2nd at South Park', end_date='1/14/2014 13:14', end_station_name='2nd at Folsom'), Row(start_date='1/14/2014 13:20', start_station_name='2nd at Folsom', end_date='1/14/2014 14:02', end_station_name='2nd at South Park'), Row(start_date='1/14/2014 16:22', start_station_name='2nd at South Park', end_date='1/14/2014 16:26', end_station_name='San Francisco Caltrain (Townsend at 4th)'), Row(start_date='1/14/2014 20:23', start_station_name='San Francisco Caltrain (Townsend at 4th)', end_date='1/14/2014 20:29', end_station_name='Embarcadero at Bryant'), Row(start_date='1/14/2014 5:35', start_station_name='Davis at Jackson', end_date='1/14/2014 5:47', end_station_name='San Francisco Caltrain (Townsend at 4th)'), Row(start_date='1/14/2014 7:03', start_station_name='San Francisco Caltrain (Townsend at 4th)', end_date='1/14/2014 7:15', end_station_name='South Van Ness at Market'), Row(start_date='1/14/2014 9:58', start_station_name='South Van Ness at Market', end_date='1/14/2014 10:10', end_station_name='Howard at 2nd'), Row(start_date='1/15/2014 10:02', start_station_name='2nd at Folsom', end_date='1/15/2014 10:06', end_station_name='Market at Sansome'), Row(start_date='1/15/2014 11:51', start_station_name='Market at Sansome', end_date='1/15/2014 11:57', end_station_name='2nd at South Park'), Row(start_date='1/15/2014 17:40', start_station_name='2nd at South Park', end_date='1/15/2014 17:46', end_station_name='Howard at 2nd'), Row(start_date='1/15/2014 18:36', start_station_name='San Francisco Caltrain 2 (330 Towns ...

# %%
# Найти количество велосипедов в системе.
bike_count=(trips_df.groupBy("bike_id").count().count())

print(bike_count)
# Out:
# 700

# %%
# Найти пользователей потративших на поездки более 3 часов.
users = (trips_df.groupBy("zip_code")
         .agg((F.sum("duration")/3600).alias("sum_duration"))
         .filter(F.col("sum_duration")>3)
         .select("zip_code", F.round("sum_duration",1).alias("sum_duration"))
         .filter(F.col("zip_code")!="nil")
         .orderBy(F.desc("sum_duration"))
).collect()

print(users)
# Out:
# [Row(zip_code='94107', sum_duration=13821.4), Row(zip_code='94105', sum_duration=7110.0), Row(zip_code='94133', sum_duration=6010.5), Row(zip_code='94102', sum_duration=5313.3), Row(zip_code='94103', sum_duration=5313.2), Row(zip_code='95531', sum_duration=4797.3), Row(zip_code='94111', sum_duration=3956.9), Row(zip_code='95112', sum_duration=3539.5), Row(zip_code='94109', sum_duration=3349.2), Row(zip_code='94040', sum_duration=2168.9), Row(zip_code='94110', sum_duration=2061.6), Row(zip_code='94117', sum_duration=1917.0), Row(zip_code='94301', sum_duration=1830.7), Row(zip_code='94041', sum_duration=1743.4), Row(zip_code='94158', sum_duration=1735.6), Row(zip_code='94306', sum_duration=1541.8), Row(zip_code='94025', sum_duration=1438.4), Row(zip_code='94108', sum_duration=1424.3), Row(zip_code='94611', sum_duration=1393.0), Row(zip_code='94010', sum_duration=1333.4), Row(zip_code='94403', sum_duration=1301.8), Row(zip_code='95110', sum_duration=1270.5), Row(zip_code='94114', sum_duration=1190.5), Row(zip_code='94501', sum_duration=1135.2), Row(zip_code='94602', sum_duration=1076.2), Row(zip_code='94303', sum_duration=1072.2), Row(zip_code='95126', sum_duration=1025.8), Row(zip_code='94112', sum_duration=1008.6), Row(zip_code='94610', sum_duration=1008.5), Row(zip_code='94404', sum_duration=997.0), Row(zip_code='94070', sum_duration=996.6), Row(zip_code='94043', sum_duration=969.9), Row(zip_code='94002', sum_duration=931.9), Row(zip_code='94402', sum_duration=917.7), Row(zip_code='94608', sum_duration=914.3), Row(zip_code='94024', sum_duration=892.0), Row(zip_code='94122', sum_duration=886.0), Row(zip_code='94131', sum_duration=873.1), Row(zip_code='94087', sum_duration=867.5), Row(zip_code='94062', sum_duration=857.4), Row(zip_code='94061', sum_duration=847.1), Row(zip_code='94115', sum_duration=835.6), Row(zip_code='95113', sum_duration=828.2), Row(zip_code='94086', sum_duration=824.1), Row(zip_code='94118', sum_duration=782.4), Row(zip_code='94063', sum_duration=757.0), Row(zip_code='95051', sum_duration=756.9), Row(zip_code='94609', sum_duration=695.3), Row(zip_code='1', sum_duration=686.5), Row(zip_code='95014', sum_duration=657.5), Row(zip_code='94121', sum_duration=656.5), Row(zip_code='94401', sum_duration=625.0), Row(zip_code='94104', sum_duration=615.5), Row(zip_code='97213', sum_duration=614.2), Row(zip_code='81', sum_duration=593.0), Row(zip_code='94030', sum_duration=588.8), Row(zip_code='94549', sum_duration=535.9), Row(zip_code='94618', sum_duration=528.0), Row(zip_code='94123', sum_duration=526.7), Row(zip_code='94612', sum_duration=516.9), Row(zip_code='94903', sum_duration=512.9), Row(zip_code='94941', sum_duration=510.3), Row(zip_code='94124', sum_duration=500.1), Row(zip_code='94014', sum_duration=489.6), Row(zip_code='94703', sum_duration=473.4), Row(zip_code='94066', sum_duration=470.6), Row(zip_code='31', sum_duration=465.9), Row(zip_code='94116', sum_duration=457.6), Row(zip_code='94127', sum_duration=431.7), Row(zip_code='94704', sum_duration=426.8), Row(zip_code='94901', sum_duration=424.6), Row(zip_code='95125', sum_duration=417.5), Row(zip_code='95008', sum_duration=410.8), Row(zip_code='89451', sum_duration=402.4), Row(zip_code='94960', sum_duration=400.0), Row(zip_code='94702', sum_duration=392.8), Row(zip_code='95118', sum_duration=389.3), Row(zip_code='94065', sum_duration=379.4), Row(zip_code='94305', sum_duration=375.5), Row(zip_code='95111', sum_duration=372.4), Row(zip_code='94705', sum_duration=370.2), Row(zip_code='86', sum_duration=369.4), Row(zip_code='94590', sum_duration=368.5), Row(zip_code='94709', sum_duration=367.7), Row(zip_code='94706', sum_duration=351.9), Row(zip_code='94132', sum_duration=340.2), Row(zip_code='94134', sum_duration=322.4), Row(zip_code='94710', sum_duration=318.7), Row(zip_code='95136', sum_duration=309.6), Row(zip_code='95129', sum_duration=308.1), Row(zip_code='90024', sum_duration=307.3), Row(zip_code='94015', sum_duration=303.3), Row(zip_code='95054', sum_ ...
